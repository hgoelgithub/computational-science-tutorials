# %% [markdown]
# # Graph Neural Networks for Toxicity

# %% [markdown]
# Conceptual intro + placeholder for PyTorch Geometric implementation

# %%
print("Use PyTorch Geometric for real implementation")
